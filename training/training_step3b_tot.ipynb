# %% [markdown]
# <a href="https://colab.research.google.com/github/federico2879/MLDL2024_semantic_segmentation/blob/master/training/training-bisenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import

# %%
# !git clone https://github.com/federico2879/MLDL2024_semantic_segmentation.git
# Out:
# Cloning into 'MLDL2024_semantic_segmentation'...
# remote: Enumerating objects: 552, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 552 (delta 117), reused 150 (delta 93), pack-reused 349
# Receiving objects: 100% (552/552), 272.11 KiB | 1.42 MiB/s, done.
# Resolving deltas: 100% (324/324), done.

# %%
import torch
from torch import nn
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms.functional import InterpolationMode
from torch.utils.data import DataLoader
import numpy as np
from MLDL2024_semantic_segmentation.datasets.cityscapes import CityScapes
from MLDL2024_semantic_segmentation.datasets.gta5 import GTA5
from MLDL2024_semantic_segmentation.models.bisenet.build_bisenet import *
from MLDL2024_semantic_segmentation.train import * 
from MLDL2024_semantic_segmentation.utils import *
from MLDL2024_semantic_segmentation.models.IOU import *

# %% [markdown]
# ## Setup

# %%
# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
# Setup fixed parameters
num_epochs = 50
num_classes = 19
batch_size = 4

# %% [markdown]
# ## Dataset

# %%
# Transformations
transform_image = {
    'train': transforms.Compose([
        transforms.Resize((1280, 720)),
        transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.05),
        transforms.RandomHorizontalFlip(0.15),
        transforms.GaussianBlur(kernel_size=3, sigma=(0.2, 0.8)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize((1024, 512)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])
}
                   
transform_target = {
    'train': transforms.Compose([
        transforms.Resize((1280, 720), interpolation=InterpolationMode.NEAREST),
    ]),
    'test': transforms.Compose([
        transforms.Resize((1024, 512), interpolation=InterpolationMode.NEAREST)
    ])
}

# %%
# Create dataloader
dataset_train = GTA5('/kaggle/input/mldl-gta5/GTA', 
                     transform = transform_image['train'], 
                     label_transform = transform_target['train'])
dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)

dataset_val = CityScapes('/kaggle/input/cityscapes/Cityscapes/Cityspaces', 
                          split = 'val', transform = transform_image['test'], 
                          label_transform = transform_target['test'])
dataloader_val = DataLoader(dataset_val, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## Network, Loss, Optimizer

# %%
# Inizialization of the model
model = BiSeNet(num_classes=num_classes, context_path="resnet18").to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 61.2MB/s]
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
# 100%|██████████| 171M/171M [00:02<00:00, 62.2MB/s]

# %%
# Define loss and optimizer
loss_fn =  nn.CrossEntropyLoss(ignore_index=255)
optimizer = torch.optim.SGD(model.parameters(), lr=2.5e-2, momentum=0.9, 
                            weight_decay=1e-4)

# %% [markdown]
# ## Training

# %%
# metrics

meanIOU_tr = np.zeros((num_epochs,1))
IOU_tr = np.zeros((num_epochs,num_classes))
loss_tr = np.zeros((num_epochs,1))


meanIOU_val = np.zeros((num_epochs,1))
IOU_val = np.zeros((num_epochs,num_classes))
loss_val = np.zeros((num_epochs,1))

# %%
## Set the random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# %%
for epoch in range(num_epochs):
    poly_lr_scheduler(optimizer, 2.5e-2, epoch, lr_decay_iter=1,
                      max_iter=num_epochs, power=0.9)
    meanIOU_tr[epoch], IOU_tr[epoch,:], loss_tr[epoch] = train(model, optimizer, dataloader_train, loss_fn, num_classes, 0)
    meanIOU_val[epoch], IOU_val[epoch,:], loss_val[epoch] = test(model, dataloader_val, loss_fn, num_classes, 0)
    print(f"epoch: {epoch + 1}, Validation IOU: {meanIOU_val[epoch,0]:.2f}")

    torch.save({
        'epoch': epoch + 1,
        'state_dict': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'meanIOU_tr': meanIOU_tr,
        'IOU_tr': IOU_tr,
        'loss_tr': loss_tr,
        'meanIOU_val': meanIOU_val,
        'IOU_val': IOU_val,
        'loss_val': loss_val
        },"checkpoint.pth.tar")
# Out:
# epoch: 1, Validation IOU: 0.17
# epoch: 2, Validation IOU: 0.18
# epoch: 3, Validation IOU: 0.18
# epoch: 4, Validation IOU: 0.18
# epoch: 5, Validation IOU: 0.21
# epoch: 6, Validation IOU: 0.20
# epoch: 7, Validation IOU: 0.23
# epoch: 8, Validation IOU: 0.23
# epoch: 9, Validation IOU: 0.21
# epoch: 10, Validation IOU: 0.22
# epoch: 11, Validation IOU: 0.22
# epoch: 12, Validation IOU: 0.22
# epoch: 13, Validation IOU: 0.23
# epoch: 14, Validation IOU: 0.22
# epoch: 15, Validation IOU: 0.22
# epoch: 16, Validation IOU: 0.23
# epoch: 17, Validation IOU: 0.24
# epoch: 18, Validation IOU: 0.21
# epoch: 19, Validation IOU: 0.23
# epoch: 20, Validation IOU: 0.22
# epoch: 21, Validation IOU: 0.20
# epoch: 22, Validation IOU: 0.19
# epoch: 23, Validation IOU: 0.20
# epoch: 24, Validation IOU: 0.21
# epoch: 25, Validation IOU: 0.19

# %%
from MLDL2024_semantic_segmentation.load_checkpoint import *

model, optimizer, start_epoch, meanIOU_tr, IOU_tr, loss_tr, meanIOU_val, IOU_val, loss_val \
= load_checkpoint(model, optimizer,"/kaggle/input/aug-j05x3-gbk3s0208/checkpoint.pth.tar")

for epoch in range(start_epoch,num_epochs):
    poly_lr_scheduler(optimizer, 2.5e-2, epoch, lr_decay_iter=1,
                      max_iter=num_epochs, power=0.9)
    meanIOU_tr[epoch], IOU_tr[epoch,:], loss_tr[epoch] = train(model, optimizer, dataloader_train, loss_fn, num_classes, 0)
    meanIOU_val[epoch], IOU_val[epoch,:], loss_val[epoch] = test(model, dataloader_val, loss_fn, num_classes, 0)
    print(f"epoch: {epoch + 1}, Validation IOU: {meanIOU_val[epoch,0]:.2f}")

    torch.save({
        'epoch': epoch + 1,
        'state_dict': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'meanIOU_tr': meanIOU_tr,
        'IOU_tr': IOU_tr,
        'loss_tr': loss_tr,
        'meanIOU_val': meanIOU_val,
        'IOU_val': IOU_val,
        'loss_val': loss_val
        },"checkpoint.pth.tar")
# Out:
# epoch: 26, Validation IOU: 0.20
# epoch: 27, Validation IOU: 0.22
# epoch: 28, Validation IOU: 0.23
# epoch: 29, Validation IOU: 0.22
# epoch: 30, Validation IOU: 0.23
# epoch: 31, Validation IOU: 0.22
# epoch: 32, Validation IOU: 0.22
# epoch: 33, Validation IOU: 0.21
# epoch: 34, Validation IOU: 0.22
# epoch: 35, Validation IOU: 0.20
# epoch: 36, Validation IOU: 0.23
# epoch: 37, Validation IOU: 0.22
# epoch: 38, Validation IOU: 0.21
# epoch: 39, Validation IOU: 0.22
# epoch: 40, Validation IOU: 0.22
# epoch: 41, Validation IOU: 0.22
# epoch: 42, Validation IOU: 0.22
# epoch: 43, Validation IOU: 0.21
# epoch: 44, Validation IOU: 0.22
# epoch: 45, Validation IOU: 0.22
# epoch: 46, Validation IOU: 0.21
# epoch: 47, Validation IOU: 0.20
# epoch: 48, Validation IOU: 0.21
# epoch: 49, Validation IOU: 0.21
# epoch: 50, Validation IOU: 0.22

# %%
# final print

print(f"Final mIOU: {meanIOU_val[epoch,0]:.2f}")
print("Final IOU classes")
print(IOU_val[epoch,:])
# Out:
# Final mIOU: 0.22
# Final IOU classes
# [7.53472003e-01 5.59558012e-02 7.16829281e-01 6.06159264e-02
#  7.34261070e-02 6.44762824e-02 4.18998308e-02 5.31590850e-03
#  7.23726526e-01 1.16697741e-01 7.67781650e-01 1.54499053e-01
#  1.57773054e-04 5.12410331e-01 7.08752974e-02 2.39532100e-03
#  0.00000000e+00 7.91041807e-04 0.00000000e+00]

# %%
# writing csv
import csv

with open('meanIOU_tr.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(meanIOU_tr)

with open('IOU_tr.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(IOU_tr)

with open('loss_tr.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(loss_tr)

with open('meanIOU_val.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(meanIOU_val)

with open('IOU_val.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(IOU_val)

with open('loss_val.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(loss_val)
